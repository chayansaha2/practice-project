# %% [markdown]
# <a href="https://colab.research.google.com/github/chayansaha2/practice-project/blob/main/scikitlearn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Loading the datasets**

# %%
from sklearn.datasets import load_diabetes
import matplotlib.pyplot as plt

X,y= load_diabetes(return_X_y=True)
X
# Out:
# array([[ 0.03807591,  0.05068012,  0.06169621, ..., -0.00259226,
#          0.01990749, -0.01764613],
#        [-0.00188202, -0.04464164, -0.05147406, ..., -0.03949338,
#         -0.06833155, -0.09220405],
#        [ 0.08529891,  0.05068012,  0.04445121, ..., -0.00259226,
#          0.00286131, -0.02593034],
#        ...,
#        [ 0.04170844,  0.05068012, -0.01590626, ..., -0.01107952,
#         -0.04688253,  0.01549073],
#        [-0.04547248, -0.04464164,  0.03906215, ...,  0.02655962,
#          0.04452873, -0.02593034],
#        [-0.04547248, -0.04464164, -0.0730303 , ..., -0.03949338,
#         -0.00422151,  0.00306441]])

# %%
y
# Out:
# array([151.,  75., 141., 206., 135.,  97., 138.,  63., 110., 310., 101.,
#         69., 179., 185., 118., 171., 166., 144.,  97., 168.,  68.,  49.,
#         68., 245., 184., 202., 137.,  85., 131., 283., 129.,  59., 341.,
#         87.,  65., 102., 265., 276., 252.,  90., 100.,  55.,  61.,  92.,
#        259.,  53., 190., 142.,  75., 142., 155., 225.,  59., 104., 182.,
#        128.,  52.,  37., 170., 170.,  61., 144.,  52., 128.,  71., 163.,
#        150.,  97., 160., 178.,  48., 270., 202., 111.,  85.,  42., 170.,
#        200., 252., 113., 143.,  51.,  52., 210.,  65., 141.,  55., 134.,
#         42., 111.,  98., 164.,  48.,  96.,  90., 162., 150., 279.,  92.,
#         83., 128., 102., 302., 198.,  95.,  53., 134., 144., 232.,  81.,
#        104.,  59., 246., 297., 258., 229., 275., 281., 179., 200., 200.,
#        173., 180.,  84., 121., 161.,  99., 109., 115., 268., 274., 158.,
#        107.,  83., 103., 272.,  85., 280., 336., 281., 118., 317., 235.,
# ...

# %%
from numpy import asarray_chkfinite
from sklearn.datasets import fetch_california_housing
import matplotlib.pyplot as plt
df = fetch_california_housing(as_frame=True).frame
df

# %%
from sklearn.datasets import make_blobs
import matplotlib.pyplot as plt
X,y = make_blobs(n_samples= 5000,centers=5)
X
y
plt.scatter(X[:,0], X[:,1], c=y)

# %% [markdown]
# **spliting the data**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
data = load_iris()
X,y = data.data, data.target
load_iris()
X_train,X_test, y_train, y_test = train_test_split(X,y,test_size=0.2)
len(X_train)
# Out:
# 120

# %%
import numpy as np
import matplotlib.pyplot as plt

counts = np.bincount(y_train)
positions = np.arange(3)
plt.bar(positions, counts)
plt.xticks(positions, data.target_names)
# Out:
# ([<matplotlib.axis.XTick at 0x7caeea8bc9e0>,
# ...
#  [Text(0, 0, 'setosa'), Text(1, 0, 'versicolor'), Text(2, 0, 'virginica')])

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split = StratifiedShuffleSplit(n_splits=1, test_size=0.2)

for train_idx, test_idx in split.split(X,y):
  X_train, X_test = X[train_idx],X[test_idx]
  y_train, y_test = y[train_idx],y[test_idx]

# %% [markdown]
# **preprocessing**

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from  sklearn.preprocessing import StandardScaler
X_train, X_test, y_train,y_test = train_test_split(X,y,test_size=0.2)
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)
X_train_scaled
# Out:
# array([[-1.02687605,  0.75951215, -1.28428175, -1.30838079],
#        [ 1.63352903, -0.17767508,  1.16739928,  0.54029854],
#        [-1.14780355,  1.22810577, -1.34129758, -1.44042932],
#        [-0.78502104,  0.99380896, -1.28428175, -1.30838079],
#        [ 2.23816654, -0.6462687 ,  1.68054182,  1.06849264],
#        [-0.90594855,  0.99380896, -1.34129758, -1.17633227],
#        [ 2.48002155,  1.69669938,  1.50949431,  1.06849264],
#        [ 0.18239898, -0.41197189,  0.42619339,  0.40825002],
#        [ 0.7870365 , -0.17767508,  0.82530425,  1.06849264],
#        [-0.18038353, -0.6462687 ,  0.42619339,  0.14415297],
#        [-0.42223853, -1.58345593, -0.02993331, -0.2519926 ],
#        [ 0.30332649, -1.11486231,  1.0533676 ,  0.2762015 ],
#        [ 1.02889151, -1.34915912,  1.16739928,  0.80439559],
#        [-0.30131103, -0.17767508,  0.19813004,  0.14415297],
#        [ 0.42425399, -0.41197189,  0.31216171,  0.14415297],
# ...
